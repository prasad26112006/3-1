# %% [markdown]
# <a href="https://colab.research.google.com/github/prasad26112006/3-1/blob/main/IRS/exp_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

topic = input("Enter topic: ")

print("1. Search all websites")
print("2. Search selected website")

choice = input("Enter choice: ")

if choice == "2":
    website = input("Enter website (example: bbc.com): ")
    query = topic + " site:" + website
else:
    query = topic

url = "https://www.google.com/search"
params = {
    "q": query,
    "tbm": "nws"
}

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, params=params, headers=headers)

soup = BeautifulSoup(response.text, "html.parser")

print("\nNews Results")
print("-" * 50)

for result in soup.select("div.SoaBEf")[:5]:
    title = result.select_one("div.n0jPhd")
    link = result.select_one("a")

    if title:
        print("Title:", title.text)

    if link:
        print("Link:", link.get("href"))

    print("-" * 50)
# Out:
# Enter topic: Enter topic: Artificial Intelligence 1. Search all websites 2. Search selected website Enter choice: 2 Enter website (example: bbc.com): bbc.com
# 1. Search all websites
# 2. Search selected website
# Enter choice: 2
# Enter website (example: bbc.com): bbc.com
#
# News Results
# --------------------------------------------------
